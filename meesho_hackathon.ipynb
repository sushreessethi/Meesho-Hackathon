# %% [markdown]
# <a href="https://colab.research.google.com/github/sushreessethi/Meesho-Hackathon/blob/main/meesho_hackathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
jina_cf166f12e14a424a9c0cc9750103e4517Q9v2eysvWMT2BPUgtcV27Z3d7FO

# %%
# %pip install llama-index-embeddings-jinaai
# %pip install llama-index-llms-openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 48.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...

# %%
# !pip install llama-index
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.0/189.0 kB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 19.3 MB/s eta 0:00:00
# ...

# %%
# !pip install Pillow

# %%
# Initilise with your api key
import os

jinaai_api_key = "jina_cf166f12e14a424a9c0cc9750103e4517Q9v2eysvWMT2BPUgtcV27Z3d7FO"
os.environ["JINAAI_API_KEY"] = jinaai_api_key

# %%
from llama_index.embeddings.jinaai import JinaEmbedding

text_embed_model = JinaEmbedding(
    api_key=jinaai_api_key,
    model="jina-embeddings-v3",
    # choose `retrieval.passage` to get passage embeddings
    task="retrieval.passage",
)

embeddings = text_embed_model.get_text_embedding("This is the text to embed")
print("Text dim:", len(embeddings))
print("Text embed:", embeddings)
# Out:
# Text dim: 1024
# ...

# %%
from llama_index.embeddings.jinaai import JinaEmbedding
from PIL import Image
import os
from numpy import dot
from numpy.linalg import norm

# Define the JinaEmbedding model
embed_model = JinaEmbedding(
    api_key=jinaai_api_key,
    model="jina-clip-v1",
)

# Local image file path
image_path = "pic.jpeg"  # Update with the correct path to your local image
im = Image.open(image_path)

# Display the image (in Jupyter or similar environments)


# Get image embedding
image_embeddings = embed_model.get_image_embedding(image_path)
print("Image dim:", len(image_embeddings))
print("Image embed:", image_embeddings[:5])

# Example text embedding for comparison
text_embeddings = embed_model.get_text_embedding(
    "neck polo"
)
print("Text dim:", len(text_embeddings))
print("Text embed:", text_embeddings[:5])

text_embeddings1 = embed_model.get_text_embedding(
    "neck round"
)
# Calculate cosine similarity between the image and text embeddings
cos_sim = dot(image_embeddings, text_embeddings) / (
    norm(image_embeddings) * norm(text_embeddings)
)
print("Cosine similarity:", cos_sim)
print(dot(image_embeddings, text_embeddings1) / (norm(image_embeddings) * norm(text_embeddings1)))
# Out:
# Image dim: 768
# Image embed: [0.045149162, 0.043739166, -0.01897616, -0.03874544, -0.008166212]
# Text dim: 768
# Text embed: [-0.022984678, 0.04845506, -0.055331092, 0.012751331, -0.042127814]
# Cosine similarity: 0.07737706523878328
# 0.1851225818971804

# %%
pip install jinaai

# %%
jinaai_api_key = os.getenv("JINAAI_API_KEY")
from jinaai import Client

client = Client(api_key=jinaai_api_key)
try:
    response = client.ping()
    print("API key is valid.")
except Exception as e:
    print(f"Authentication failed: {e}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-67cfb0066d14> in <cell line: 2>()
#       1 jinaai_api_key = os.getenv("JINAAI_API_KEY")
# ----> 2 from jinaai import Client
#       3
#       4 client = Client(api_key=jinaai_api_key)
#       5 try:
#
# ImportError: cannot import name 'Client' from 'jinaai' (/usr/local/lib/python3.10/dist-packages/jinaai/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
attributes = {
    "attr_1": ['black', 'red', 'navy blue', 'maroon', 'green', 'pink', 'blue', 'purple', 'grey', 'yellow', 'white', 'multicolor', 'orange'],
    "attr_2": ['straight', 'a-line'],
    "attr_3": ['knee length', 'calf length'],
    "attr_4": ['daily', 'party'],
    "attr_5": ['net', 'default'],
    "attr_6": ['solid', 'default'],
    "attr_7": ['solid', 'default'],
    "attr_8": ['three-quarter sleeves', 'short sleeves', 'sleeveless'],
    "attr_9": ['regular', 'sleeveless']
}

# %%
from PIL import Image
import requests

from transformers import CLIPProcessor, CLIPModel

model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")


image = Image.open("008770.jpg")

inputs = processor(text= ['occasion party', 'occasion traditional', 'occassion daily', 'occassion wedding'], images=image, return_tensors="pt", padding=True)

outputs = model(**inputs)
logits_per_image = outputs.logits_per_image  # this is the image-text similarity score
probs = logits_per_image.softmax(dim=1)  # we can take the softmax to get the label probabilities

# %%
print(probs)
print(logits_per_image)
# Out:
# tensor([[0.0279, 0.7122, 0.0176, 0.2423]], grad_fn=<SoftmaxBackward0>)
# tensor([[19.6870, 22.9254, 19.2253, 21.8473]], grad_fn=<TBackward0>)

# %%
print(probs)
# Out:
# tensor([[0.6635, 0.2398, 0.0801, 0.0166]], grad_fn=<SoftmaxBackward0>)

# %%
from PIL import Image
from transformers import CLIPProcessor, CLIPModel
import torch

# Load the CLIP model and processor
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# Load and preprocess the image
image = Image.open("031964.jpg")
image_inputs = processor(images=image, return_tensors="pt")

# Define the attribute categories
attributes = {
    "attr_1": ['black', 'red', 'navy blue', 'maroon', 'green', 'pink', 'blue', 'purple', 'grey', 'yellow', 'white', 'multicolor', 'orange'],
    "attr_2": ['straight', 'a-line'],
    "attr_3": ['knee length', 'calf length'],
    "attr_4": ['daily', 'party'],
    "attr_5": ['net', 'default'],
    "attr_6": ['solid', 'default'],
    "attr_7": ['solid', 'default'],
    "attr_8": ['three-quarter sleeves', 'short sleeves', 'sleeveless'],
    "attr_9": ['regular', 'sleeveless']
}

# Encode the image
image_features = model.get_image_features(**image_inputs)

# Function to encode each attribute list and compute similarity scores
def compute_similarity(attributes, image_features):
    similarity_scores = {}
    for attr, values in attributes.items():
        # Encode text values
        text_inputs = processor(text=values, return_tensors="pt", padding=True)
        text_features = model.get_text_features(**text_inputs)

        # Compute similarity between the image and each text value
        image_features_normalized = image_features / image_features.norm(dim=-1, keepdim=True)
        text_features_normalized = text_features / text_features.norm(dim=-1, keepdim=True)
        similarity = (image_features_normalized @ text_features_normalized.T).squeeze(0)

        # Apply softmax to get probability distribution
        probabilities = similarity.softmax(dim=0)
        similarity_scores[attr] = {value: prob.item() for value, prob in zip(values, probabilities)}
    return similarity_scores

# Compute similarity scores
similarity_scores = compute_similarity(attributes, image_features)

# Display the similarity scores for each attribute
for attr, scores in similarity_scores.items():
    print(f"{attr} similarity scores:")
    for value, score in scores.items():
        print(f"  {value}: {score:.4f}")
# Out:
# attr_1 similarity scores:
#   black: 0.0774
#   red: 0.0752
#   navy blue: 0.0815
#   maroon: 0.0762
#   green: 0.0767
#   pink: 0.0747
#   blue: 0.0786
#   purple: 0.0772
#   grey: 0.0781
#   yellow: 0.0760
#   white: 0.0768
#   multicolor: 0.0756
#   orange: 0.0760
# attr_2 similarity scores:
#   straight: 0.4891
#   a-line: 0.5109
# attr_3 similarity scores:
#   knee length: 0.4956
#   calf length: 0.5044
# attr_4 similarity scores:
#   daily: 0.4977
#   party: 0.5023
# attr_5 similarity scores:
#   net: 0.4984
#   default: 0.5016
# attr_6 similarity scores:
#   solid: 0.4973
#   default: 0.5027
# attr_7 similarity scores:
#   solid: 0.4973
#   default: 0.5027
# attr_8 similarity scores:
#   three-quarter sleeves: 0.3375
#   short sleeves: 0.3334
#   sleeveless: 0.3291
# attr_9 similarity scores:
#   regular: 0.4956
#   sleeveless: 0.5044

# %%
from PIL import Image
import torch
from transformers import CLIPProcessor, CLIPModel

# Load pre-trained CLIP model and processor
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# Load the image
image = Image.open("031964.jpg")

# Define attributes and their possible values
attributes = {
    "color": ['black', 'red', 'navy blue', 'maroon', 'green', 'pink', 'blue', 'purple', 'grey', 'yellow', 'white', 'multicolor', 'orange'],
    "fit_shape": ['straight', 'a-line'],
    "length": ['knee length', 'calf length'],
    "occasion": ['daily', 'party'],
    "ornamentation": ['net', 'default'],
    "pattern": ['solid', 'default'],
    "print_or_pattern_type": ['solid', 'default'],
    "sleeve_length": ['three-quarter sleeves', 'short sleeves', 'sleeveless'],
    "sleeve_styling": ['regular', 'sleeveless']
}

# Dictionary to store similarity scores for each attribute-value pair
similarity_scores = {}

# Iterate over each attribute and its values
for attribute, values in attributes.items():
    attribute_scores = {}  # Temporary dictionary to store scores for each value in the attribute

    for value in values:
        # Combine the attribute and value as a text prompt
        promt_list =[]
        prompt = f"{attribute} is {value}"
        promt_list.append(prompt)

        # Process the image and text prompt
    print(promt_list)
    inputs = processor(text=promt_list, images=image, return_tensors="pt", padding=True)

        # Get the model output
    outputs = model(**inputs)
    logits_per_image = outputs.logits_per_image  # This is the image-text similarity score
    probs = logits_per_image.softmax(dim=1)  # Convert to probabilities


    # Add the scores for this attribute to the main dictionary
    similarity_scores[attribute] = probs
    print(f"\nAttribute: {attribute}:{probs}")
# Out:
# config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-f60114a14c39> in <cell line: 10>()
#       8
#       9 # Load the image
# ---> 10 image = Image.open("031964.jpg")
#      11
#      12 # Define attributes and their possible values
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3467
#    3468     if filename:
# ...

# %%
from PIL import Image
import torch
from transformers import CLIPProcessor, CLIPModel

# Load pre-trained CLIP model and processor
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# Load the image
image = Image.open("031964.jpg")

# Define attributes and their possible values
attributes = {
    "color": ['black', 'red', 'navy blue', 'maroon', 'green', 'pink', 'blue', 'purple', 'grey', 'yellow', 'white', 'multicolor', 'orange'],
    "fit_shape": ['straight', 'a-line'],
    "length": ['knee length', 'calf length'],
    "occasion": ['daily', 'party'],
    "ornamentation": ['net', 'default'],
    "pattern": ['solid', 'default'],
    "print_or_pattern_type": ['solid', 'default'],
    "sleeve_length": ['three-quarter sleeves', 'short sleeves', 'sleeveless'],
    "sleeve_styling": ['regular', 'sleeveless']
}

# Dictionary to store similarity scores for each attribute-value pair
similarity_scores = {}

# Create a list of prompts for each attribute
prompts = {}

# Iterate over each attribute and its values to create prompts
for attribute, values in attributes.items():
    prompt_list = []  # Temporary list to store prompts for the current attribute
    for value in values:
        # Combine the attribute and value as a text prompt
        prompt = f"{attribute} is {value}"
        prompt_list.append(prompt)
    # Store the list of prompts for this attribute
    prompts[attribute] = prompt_list

# Process the image and the list of prompts
for attribute, prompt_list in prompts.items():
    attribute_scores = {}  # Temporary dictionary to store scores for each value in the attribute

    # Process the image and text prompts together
    inputs = processor(text=prompt_list, images=image, return_tensors="pt", padding=True)

    # Get the model output
    outputs = model(**inputs)
    logits_per_image = outputs.logits_per_image  # This is the image-text similarity score
    probs = logits_per_image.softmax(dim=1)  # Convert to probabilities

    # Store the probability scores for each value of the current attribute


    print(f"\nAttribute: {attribute}, Scores: {probs}")

# Output similarity scores
print("\nFinal Similarity Scores:", similarity_scores)
# Out:
# Attribute: color, Scores: tensor([[1.9001e-02, 6.2413e-04, 8.3427e-01, 3.6435e-03, 2.0381e-03, 2.0509e-04,
#          2.9790e-02, 2.6700e-03, 6.5158e-02, 1.0163e-03, 2.1656e-02, 1.8657e-02,
#          1.2764e-03]], grad_fn=<SoftmaxBackward0>)
#
# Attribute: fit_shape, Scores: tensor([[0.0835, 0.9165]], grad_fn=<SoftmaxBackward0>)
#
# Attribute: length, Scores: tensor([[0.2622, 0.7378]], grad_fn=<SoftmaxBackward0>)
#
# Attribute: occasion, Scores: tensor([[0.4913, 0.5087]], grad_fn=<SoftmaxBackward0>)
#
# Attribute: ornamentation, Scores: tensor([[0.4947, 0.5053]], grad_fn=<SoftmaxBackward0>)
#
# Attribute: pattern, Scores: tensor([[0.0889, 0.9111]], grad_fn=<SoftmaxBackward0>)
#
# Attribute: print_or_pattern_type, Scores: tensor([[0.4930, 0.5070]], grad_fn=<SoftmaxBackward0>)
#
# Attribute: sleeve_length, Scores: tensor([[0.5072, 0.2733, 0.2196]], grad_fn=<SoftmaxBackward0>)
#
# Attribute: sleeve_styling, Scores: tensor([[0.4660, 0.5340]], grad_fn=<SoftmaxBackward0>)
#
# ...

# %%
kurti_dict={"sleeve below elbow" : "three-quarter sleeves","non-net":"default","non-solid":"default","more than two colors of kurti":"multicolor"}

# %%
from PIL import Image
import torch
from transformers import CLIPProcessor, CLIPModel

# Load pre-trained CLIP model and processor
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
# for image in images:
# Load the image
image = Image.open("031966.jpg")
#three quarter modify
# Define attributes and their possible values
attributes = {
    "color": ['black', 'red', 'navy blue', 'maroon', 'green', 'pink', 'blue', 'purple', 'grey', 'yellow', 'white', 'more than two colors of kurti', 'orange'],
    "fit_shape": ['straight', 'a-line'],
    "length": ['knee length', 'calf length'],
    "occasion": ['daily', 'party'],
    "ornamentation": ['net', 'non-net'],
    "pattern": ['solid', 'non-solid'],
    "print_or_pattern_type": ['solid', 'non-solid'],
    "sleeve_length": ['sleeve below elbow', 'short sleeves', 'sleeveless'],
    "sleeve_styling": ['regular', 'sleeveless']
}

# Dictionary to store similarity scores for each attribute-value pair
similarity_scores = {}

# Create a list of prompts for each attribute
prompts = {}

# Iterate over each attribute and its values to create prompts
for attribute, values in attributes.items():
    prompt_list = []  # Temporary list to store prompts for the current attribute
    for value in values:
        if attribute=='occasion':
           prompt = f"Kurti can be worn on {value} {attribute}"
           prompt_list.append(prompt)
        else:
        # Combine the attribute and value as a text prompt
          prompt = f"Kurti's {attribute} type is {value}"
          prompt_list.append(prompt)
    # Store the list of prompts for this attribute
    prompts[attribute] = prompt_list

# Process the image and the list of prompts
for attribute, prompt_list in prompts.items():
    attribute_scores = {}  # Temporary dictionary to store scores for each value in the attribute

    # Process the image and text prompts together
    inputs = processor(text=prompt_list, images=image, return_tensors="pt", padding=True)

    # Get the model output
    outputs = model(**inputs)
    logits_per_image = outputs.logits_per_image  # This is the image-text similarity score
    probs = logits_per_image.softmax(dim=1)  # Convert to probabilities

    # Store the probability scores for each value of the current attribute
    for idx, value in enumerate(attributes[attribute]):
        attribute_scores[value] = probs[0][idx].item()  # Convert tensor to scalar value and store

    # Store the attribute scores in the main similarity_scores dictionary
    similarity_scores[attribute] = attribute_scores

    # Print out the similarity scores for the current attribute
    max_score = max(attribute_scores.values())

    # Find the attribute(s) with the maximum score
    for att, score in attribute_scores.items():
        if score == max_score:
          if att in kurti_dict:
            print(f"{kurti_dict[att]}: {score}")
          else:
            print(f"{att}: {score}")
# Out:
# multicolor: 0.2900373935699463
# a-line: 0.9071497917175293
# calf length: 0.9303926229476929
# daily: 0.5378000736236572
# default: 0.501896858215332
# default: 0.7631181478500366
# default: 0.6084809303283691
# short sleeves: 0.3854718804359436
# regular: 0.6704797148704529

# %%
top_dict={"till waist":"regular","square shaped":"boxy","normal":"regular"}
# Out:
#   File "<ipython-input-13-411477818159>", line 1
#     top_dict={"till waist":"regular","square shaped":"boxy","normal":}
#                                                                     ^
# SyntaxError: expression expected after dictionary key and ':'

# %%
from PIL import Image
import torch
from transformers import CLIPProcessor, CLIPModel

# Load pre-trained CLIP model and processor
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# Load the image
image = Image.open("034206.jpg")

# Define attributes and their possible values
attributes = {
        "color": ['multicolor', 'yellow', 'black', 'more than one color', 'pink', 'maroon', 'white'],
        "fit_shape": ['loose', 'square shaped', 'regular'],
        "length": ['long', 'crop', 'till waist'],
        "pattern": ['default', 'solid', 'printed'],
        "print_or_pattern_type": ['default', 'quirky', 'solid', 'graphic', 'funky print', 'typography'],
        "sleeve_length": ['default', 'long sleeves', 'short sleeves'],
        "sleeve_styling": ['regular sleeves', 'cuffed sleeves'],
        "surface_styling": ['default', 'applique']
}

# Dictionary to store similarity scores for each attribute-value pair
similarity_scores = {}

# Create a list of prompts for each attribute
prompts = {}

# Iterate over each attribute and its values to create prompts
for attribute, values in attributes.items():
    prompt_list = []  # Temporary list to store prompts for the current attribute
    for value in values:
        # Combine the attribute and value as a text prompt
        prompt = f"Women top's {attribute} is {value}"
        prompt_list.append(prompt)
    # Store the list of prompts for this attribute
    prompts[attribute] = prompt_list

for attribute, prompt_list in prompts.items():
    attribute_scores = {}  # Temporary dictionary to store scores for each value in the attribute

    # Process the image and text prompts together
    inputs = processor(text=prompt_list, images=image, return_tensors="pt", padding=True)

    # Get the model output
    outputs = model(**inputs)
    logits_per_image = outputs.logits_per_image  # This is the image-text similarity score
    probs = logits_per_image.softmax(dim=1)  # Convert to probabilities

    # Store the probability scores for each value of the current attribute
    for idx, value in enumerate(attributes[attribute]):
        attribute_scores[value] = probs[0][idx].item()  # Convert tensor to scalar value and store

    # Store the attribute scores in the main similarity_scores dictionary
    similarity_scores[attribute] = attribute_scores

    # Print out the similarity scores for the current attribute
    max_score = max(attribute_scores.values())

    # Find the attribute(s) with the maximum score
    for att, score in attribute_scores.items():
        if score == max_score:
          if att in kurti_dict:
            print(f"{kurti_dict[att]}: {score}")
          else:
            print(f"{att}: {score}")
# Out:
# multicolor: 0.47055575251579285
# boxy: 0.42048943042755127
# crop: 0.7087029814720154
# printed: 0.41284462809562683
# solid: 0.4070855379104614
# short sleeves: 0.791490912437439
# cuffed sleeves: 0.5519105195999146
# applique: 0.7587697505950928

# %%
print(attribute_scores)
# Out:
# {'default': 0.24123024940490723, 'applique': 0.7587697505950928}

# %%
tshirt_dict={"collared":"polo",'non black-white and non multiple tshirt of same style-different color':"default","more than one tshirt of same style with different colors":"multicolor","black base t-shirt":"black","white base t-shirt":"white","non-solid and no letters but some pattern":"default","below elbow":"long sleeves"}

# %% [markdown]
# mens shirt

# %%
from PIL import Image
import torch
from transformers import CLIPProcessor, CLIPModel

# Load pre-trained CLIP model and processor
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
# for image in images:
# Load the image
image = Image.open("000006.jpg")
#three quarter modify
# Define attributes and their possible values
attributes = {
        "color": ['non black-white and non multiple tshirt of same style-different color', 'more than one tshirt of same style with different colors', 'black base t-shirt', 'white base t-shirt'],
        "neck": ['round', 'collared'],
        "pattern": ['printed', 'solid'],
        "print_or_pattern_type": ['non-solid and no letters but some pattern', 'solid', 'typography'],
        "sleeve_length": ['short sleeves', 'below elbow']
}

# Dictionary to store similarity scores for each attribute-value pair
similarity_scores = {}

# Create a list of prompts for each attribute
prompts = {}

# Iterate over each attribute and its values to create prompts
for attribute, values in attributes.items():
    prompt_list = []  # Temporary list to store prompts for the current attribute
    for value in values:
        if attribute=='color':
           prompt = f"image has is {value}"
           prompt_list.append(prompt)
        else:
        # Combine the attribute and value as a text prompt
          prompt = f"T-shirt {attribute} type is {value}"
          prompt_list.append(prompt)
    # Store the list of prompts for this attribute
    prompts[attribute] = prompt_list

# Process the image and the list of prompts
for attribute, prompt_list in prompts.items():
    attribute_scores = {}  # Temporary dictionary to store scores for each value in the attribute

    # Process the image and text prompts together
    inputs = processor(text=prompt_list, images=image, return_tensors="pt", padding=True)

    # Get the model output
    outputs = model(**inputs)
    logits_per_image = outputs.logits_per_image  # This is the image-text similarity score
    probs = logits_per_image.softmax(dim=1)  # Convert to probabilities

    # Store the probability scores for each value of the current attribute
    for idx, value in enumerate(attributes[attribute]):
        attribute_scores[value] = probs[0][idx].item()  # Convert tensor to scalar value and store

    # Store the attribute scores in the main similarity_scores dictionary
    similarity_scores[attribute] = attribute_scores

    # Print out the similarity scores for the current attribute
    max_score = max(attribute_scores.values())

    # Find the attribute(s) with the maximum score
    for att, score in attribute_scores.items():
        if score == max_score:
          if att in tshirt_dict:
            print(f"{tshirt_dict[att]}: {score}")
          else:
            print(f"{att}: {score}")
# Out:
# multicolor: 0.5552266240119934
# polo: 0.7113658785820007
# printed: 0.6647558808326721
# solid: 0.6970775127410889
# short sleeves: 0.8681795597076416

# %% [markdown]
# Women Tops & Tunics

# %%
womenTop_dict = {'two or more tshirts with different color or anything except black, navy blue, red, maroom, white, green, blue, pink, yellow, peach': "default", "more than one color": "multicolor", 'not tight fitted':"regular", 'fitted or slim fit': "fitted", 'loose box like fit':"boxy", 'above waist':"crop", "anything except high, round neck, stylised, sweetheart neck, v-neck, square neck" : "default", 'above elbow':"short sleeves", 'below elbow but not full hands':"three-quarter sleeves", }

# %%
from PIL import Image
import torch
from transformers import CLIPProcessor, CLIPModel

# Load pre-trained CLIP model and processor
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
# for image in images:
# Load the image
image = Image.open("069922.jpg")
#three quarter modify
# Define attributes and their possible values
attributes = {
        "color": ['black', 'navy blue', 'red', 'two or more tshirts/tops with different color or anything colors except black, navy blue, red, maroom, white, green, blue, pink, yellow, peach', 'maroon', 'white', 'green', 'blue', 'pink', 'yellow', 'peach', 'more than one colors in a top'],
        "fit_shape": ['long loose', 'right size', 'loose, square-like shape and straight lines', 'default'],
        "length": ['short and above waist', 'regular or tucked in top'],
        "neck_collar": ['high', 'round', 'stylised', 'sweetheart', 'v', 'square', 'anything except high, round , stylised, sweetheart , v or square shape'],
        "occasion": ['casual', 'party'],
        "pattern": ['default', 'pattern', 'plain and no pattern'],
        "print_or_pattern_type": ['solid', 'typography', 'graphic', 'non-solid and no letters but some pattern', 'abstract pattern', 'floral'],
        "sleeve_length": ['above elbow and short', 'zero', 'small than regualr sleeves', 'full hands till wrists'],
        "sleeve_styling": ['regular sleeves', 'default', 'sleeveless', 'puff sleeves'],
        "surface_styling": ['knitted', 'no surface styling and no strings and basic', 'frills', 'strings or threads tied around the waist area except belt', 'strings cords tied around anywhere except waist', ' stitched pieces of fabric onto the main fabric']

}

# Dictionary to store similarity scores for each attribute-value pair
similarity_scores = {}

# Create a list of prompts for each attribute
prompts = {}

# Iterate over each attribute and its values to create prompts
for attribute, values in attributes.items():
    prompt_list = []  # Temporary list to store prompts for the current attribute
    for value in values:
        if attribute=='occassion':
           prompt = f"Top can be worn on {value} occassion"
           prompt_list.append(prompt)

        elif attribute=='color':
           prompt = f"Top'/s color {value}"
           prompt_list.append(prompt)

        elif attribute=='neck_collar':
           prompt = f"Neck of the top is {value}"
           prompt_list.append(prompt)

        elif attribute=='fit_shape':
           prompt = f"top fitting is{value}"
           prompt_list.append(prompt)

        elif attribute=='length':
           prompt = f"top length is {value}"
           prompt_list.append(prompt)
        elif attribute=='sleeve_length':
           prompt = f"top sleeve length is {value}"
           prompt_list.append(prompt)
        else:
        # Combine the attribute and value as a text prompt
          prompt = f"T-shirt {attribute} is {value}"
          prompt_list.append(prompt)
    # Store the list of prompts for this attribute
    prompts[attribute] = prompt_list

# Process the image and the list of prompts
for attribute, prompt_list in prompts.items():
    attribute_scores = {}  # Temporary dictionary to store scores for each value in the attribute

    # Process the image and text prompts together
    inputs = processor(text=prompt_list, images=image, return_tensors="pt", padding=True)

    # Get the model output
    outputs = model(**inputs)
    logits_per_image = outputs.logits_per_image  # This is the image-text similarity score
    probs = logits_per_image.softmax(dim=1)  # Convert to probabilities

    # Store the probability scores for each value of the current attribute
    for idx, value in enumerate(attributes[attribute]):
        attribute_scores[value] = probs[0][idx].item()  # Convert tensor to scalar value and store

    # Store the attribute scores in the main similarity_scores dictionary
    similarity_scores[attribute] = attribute_scores

    # Print out the similarity scores for the current attribute
    max_score = max(attribute_scores.values())

    # Find the attribute(s) with the maximum score
    for att, score in attribute_scores.items():
        if score == max_score:
          if att in womenTop_dict:
            print(f"{womenTop_dict[att]}: {score}")
          else:
            print(f"{att}: {score}")
# Out:
# pink: 0.3649633526802063
# right size: 0.5549359917640686
# regular or tucked in top: 0.6296620965003967
# sweetheart: 0.3181520700454712
# casual: 0.6617623567581177
# plain and no pattern: 0.6461624503135681
# solid: 0.5725396871566772
# above elbow and short: 0.665521502494812
# regular sleeves: 0.6154994964599609
# strings or threads tied around the waist area except belt: 0.7012415528297424
